ltk.sent_tokenize(paragraph)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
sentence
# Out:
# ['Every day you wake up, you face a choice.',
#  'The choice between giving up and showing up.',
#  'Even when your body is tired.',
#  'Even when your mind is screaming, “I can’t.”\n\nSuccess is not magic.',
#  'It is built quietly, minute by minute, step by step.',
#  'It is built in the moments nobody notices.',
#  'The hours you spend studying when everyone else is relaxing.',
#  'The extra effort when everyone else stops.',
#  'You may feel invisible.',
#  'You may feel like nothing is changing.',
#  'But change is happening inside you.',
#  'Every small step, every extra problem solved, every sentence read, is shaping your future.',
#  'It doesn’t matter if progress is slow.',
#  'It doesn’t matter if results aren’t visible yet.',
#  'The seed doesn’t sprout the day it is planted.',
#  'It grows in silence, deep under the soil, until it is ready to break the surface.',
#  'Tiredness is not your enemy.',
#  'It is proof that you are pushing yourself.',
# ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
for i in range(len(sentence)):
  words = nltk.word_tokenize(sentence[i])
  words = [word for word in words if word not in set(stopwords.words('english'))]
  pos_tag= nltk.pos_tag(words)
  print(pos_tag)
# Out:
# [('Every', 'DT'), ('day', 'NN'), ('wake', 'VB'), (',', ','), ('face', 'NN'), ('choice', 'NN'), ('.', '.')]
# [('The', 'DT'), ('choice', 'NN'), ('giving', 'VBG'), ('showing', 'NN'), ('.', '.')]
# [('Even', 'RB'), ('body', 'NN'), ('tired', 'VBD'), ('.', '.')]
# [('Even', 'RB'), ('mind', 'RBR'), ('screaming', 'NN'), (',', ','), ('“', 'VBP'), ('I', 'PRP'), ('’', 'VBP'), ('t.', 'JJ'), ('”', 'NNP'), ('Success', 'NNP'), ('magic', 'NN'), ('.', '.')]
# [('It', 'PRP'), ('built', 'VBD'), ('quietly', 'RB'), (',', ','), ('minute', 'JJ'), ('minute', 'NN'), (',', ','), ('step', 'JJ'), ('step', 'NN'), ('.', '.')]
# [('It', 'PRP'), ('built', 'VBD'), ('moments', 'NNS'), ('nobody', 'NN'), ('notices', 'NNS'), ('.', '.')]
# [('The', 'DT'), ('hours', 'NNS'), ('spend', 'VBP'), ('studying', 'VBG'), ('everyone', 'NN'), ('else', 'RB'), ('relaxing', 'VBG'), ('.', '.')]
# [('The', 'DT'), ('extra', 'JJ'), ('effort', 'NN'), ('everyone', 'NN'), ('else', 'JJ'), ('stops', 'NNS'), ('.', '.')]
# ...

# %%
sentence
# Out:
# ['Every day you wake up, you face a choice.',
#  'The choice between giving up and showing up.',
#  'Even when your body is tired.',
#  'Even when your mind is screaming, “I can’t.”\n\nSuccess is not magic.',
#  'It is built quietly, minute by minute, step by step.',
#  'It is built in the moments nobody notices.',
#  'The hours you spend studying when everyone else is relaxing.',
#  'The extra effort when everyone else stops.',
#  'You may feel invisible.',
#  'You may feel like nothing is changing.',
#  'But change is happening inside you.',
#  'Every small step, every extra problem solved, every sentence read, is shaping your future.',
#  'It doesn’t matter if progress is slow.',
#  'It doesn’t matter if results aren’t visible yet.',
#  'The seed doesn’t sprout the day it is planted.',
#  'It grows in silence, deep under the soil, until it is ready to break the surface.',
#  'Tiredness is not your enemy.',
#  'It is proof that you are pushing yourself.',
# ...

# %%
for i in "Taj Mahal is a beautiful building in Agra".split():
  print(i)
# Out:
# Taj
# Mahal
# is
# a
# beautiful
# building
# in
# Agra
